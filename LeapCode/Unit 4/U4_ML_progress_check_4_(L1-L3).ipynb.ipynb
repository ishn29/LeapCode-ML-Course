# %% [markdown]
# # ***Machine Learning | UNIT 4: Smarter Models | PROGRESS CHECK 4***

# %% [markdown]
# ### Problem 1

# %% [markdown]
# What is overfitting?
#
# A. The model is too simple and misses patterns
# B. The model fits the training data perfectly but does poorly on new data
# C. The model works perfectly on all data
# D. The model has no patterns at all

# %% [markdown]
# **Put your answer here**
#
# ---

# %% [markdown]
# ### Problem 2

# %% [markdown]
# What is underfitting?
#
# A. The model is too complex
# B. The model is too simple and misses important patterns
# C. The model makes perfect predictions
# D. The model always predicts the same value

# %% [markdown]
# **Put your answer here**
#
# ---

# %% [markdown]
# ### Problem 3

# %% [markdown]
# Which model would likely overfit?
#
# A. A model with just one line through the data
# B. A model that memorizes every point exactly
# C. A model that generalizes to new data
# D. A model that uses only averages

# %% [markdown]
# **Put your answer here**
#
# ---

# %% [markdown]
# ### Problem 4

# %% [markdown]
# What does a decision tree do?
#
# A. Draws a line through the data
# B. Splits the data into smaller groups using rules
# C. Randomly guesses values
# D. Predicts numbers using only one feature

# %% [markdown]
# **Put your answer here**
#
# ---

# %% [markdown]
# ### Problem 5

# %% [markdown]
# True or False
#
# Decision trees can be used for both classification and regression.

# %% [markdown]
# **Put your answer here**
#
# ---

# %% [markdown]
# ### Problem 6

# %% [markdown]
# What is a random forest made of?
#
# A. One big decision tree
# B. A group of logistic regression models
# C. Many decision trees that vote together
# D. One long if-else statement

# %% [markdown]
# **Put your answer here**
#
# ---

# %% [markdown]
# ### Problem 7

# %% [markdown]
# Why is a random forest better than a single tree?
#
# A. It memorizes data
# B. It makes slower predictions
# C. It reduces overfitting by combining many trees
# D. It ignores all small patterns

# %% [markdown]
# **Put your answer here**
#
# ---

# %% [markdown]
# ### Problem 8

# %% [markdown]
# What is feature importance, and why is it useful?
#
# A. It tells you which model is the most important
# B. It shows which features (columns) helped the model the most in making predictions
# C. It removes the least important rows in the dataset
# D. It sorts the data in order of size

# %% [markdown]
# **Put your answer here**
#
# ---
