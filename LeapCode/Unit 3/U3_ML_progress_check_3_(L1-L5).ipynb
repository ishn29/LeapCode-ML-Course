# %% [markdown]
# # ***Machine Learning | UNIT 3: EDA | PROGRESS CHECK 3***

# %% [markdown]
# ### Problem 1

# %% [markdown]
# What does `df.head()` do in pandas?
#
# A. Shows the last 5 rows
# B. Shows the first 5 rows
# C. Deletes missing values
# D. Loads a dataset

# %% [markdown]
# **Put your answer here**
#
# ---

# %% [markdown]
# ### Problem 2

# %% [markdown]
# Fill in the blanks to find the number of missing values in each column in the dataset
#
# `df.______.____()`

# %% [markdown]
# **Put your answer here**
#
# ---

# %% [markdown]
# ### Problem 3

# %% [markdown]
# What do you learn from a boxplot?
#
# A. Only the average
# B. The shape of the image
# C. The range, median, and outliers of a feature
# D. The categories of the variable

# %% [markdown]
# **Put your answer here**
#
# ---

# %% [markdown]
# ### Problem 4

# %% [markdown]
# What is an outlier?
#
# A. A missing value
# B. A value that is very far from others
# C. A category column
# D. The last row of the dataset

# %% [markdown]
# **Put your answer here**
#
# ---

# %% [markdown]
# ### Problem 5

# %% [markdown]
# True or False:
#
# You should always remove outliers no matter what.

# %% [markdown]
# **Put your answer here**
#
# ---

# %% [markdown]
# ### Problem 6

# %% [markdown]
# Which plot helps you spot outliers easily?
#
# A. Histogram
# B. Scatter plot
# C. Box plot
# D. Line plot

# %% [markdown]
# **Put your answer here**
#
# ---

# %% [markdown]
# ### Problem 7

# %% [markdown]
# When should you use the mean to fill in missing values?
#
# A. When the data is numeric and has a normal distribution
# B. When it's a text column
# C. When there are no missing values
# D. When you want to group the data

# %% [markdown]
# **Put your answer here**
#
# ---

# %% [markdown]
# ### Problem 8
#
# What does label encoding do?
#
# A. It turns text categories into numbers like 0, 1, 2, etc.
# B. It deletes all the labels in the data
# C. It fills in missing values with labels
# D. It changes numbers into pictures

# %% [markdown]
# **Put your answer here**
#
# ---

# %% [markdown]
# ### Fill in the Blanks Below (One Hot Encoding)

# %% [markdown]
# Here we have a dataset that includes the a fruit and its color. The color of the fruit is a categorical value.

# %%
import pandas as pd

# Sample dataset with a categorical column
data = {
    "fruit": ["apple", "banana", "apple", "grape", "banana"],
    "color": ["red", "yellow", "green", "purple", "yellow"]
}

df = pd.DataFrame(data)
print(df)

# %% [markdown]
# We want to use OneHotEncoding to convert the categorical values to numerical values.

# %% [markdown]
# Step 1: Import OneHotEncoding from sklearn

# %%
# Hint: What are we importing?
from sklearn.preprocessing import _________

# %% [markdown]
# Step 2: Create and fit the Encoder to transform the dataset

# %%
# Create the encoder
encoder = OneHotEncoder(sparse_output=False)

# Fit and transform the "color" column
# Hint: What do we use to fit and transform at the same time
encoded_array = encoder._________(df[["color"]])

# %% [markdown]
# Step 3: Create new dataframe with new column names

# %%
# This step you don't have to fill in, but make sure you understand this

encoded_df = pd.DataFrame(
    encoded_array,
    columns=encoder.get_feature_names_out(["color"])
)

# %% [markdown]
# Step 4: Combine the new and old dataframes

# %%
# Hint: What pandas command do we use to combine two dataframes
df_encoded = pd.______([df, encoded_df], axis=1)
print(df_encoded)
