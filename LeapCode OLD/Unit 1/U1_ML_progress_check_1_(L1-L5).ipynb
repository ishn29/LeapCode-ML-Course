# %% [markdown]
# # ***Machine Learning | UNIT 1: Intro to Machine Learning | PROGRESS CHECK 1***

# %% [markdown]
# ### Problem 1
#
# Briefly describe the difference between supervised and unsupervised learning. Give one example of each

# %% [markdown]
# **Type Here**
#
# ---

# %% [markdown]
# ### Problem 2
#
# In unsupervised learning, what is missing from the dataset?
#
# A. The input features
# B. The answers or labels
# C. The file format
# D. The learning rate

# %% [markdown]
# **Put your answer here**
#
# ---

# %% [markdown]
# ### Problem 3
#
# Match the parts of a neural network:
#
# | Term            | Description                                   |
# |-----------------|-----------------------------------------------|
# | Input Layer     | _________                                      |
# | Hidden Layer    | _________                                      |
# | Output Layer    | _________                                      |
#
# Options:
# A. Makes the final prediction
# B. Where the data first enters the network
# C. Layers that do the thinking in between

# %% [markdown]
# **Put the order of your answers here**
#
# ---

# %% [markdown]
# ### Problem 4

# %% [markdown]
# What is a "feature" in a dataset?
#
# A. A table of scores
# B. A column that holds input values
# C. A file format
# D. The correct answer

# %% [markdown]
# **Put your answer here**
#
# ---

# %% [markdown]
# ### Problem 5

# %% [markdown]
# What is the "target" in supervised learning?
#
# A. The number of rows
# B. The column with missing values
# C. The column we want to predict
# D. The dataset’s file name

# %% [markdown]
# **Put your answer here**
#
# ---

# %% [markdown]
# ### Problem 6
#
# Why is it important to explore a dataset before training a machine learning model? Briefly explain your answer in 2-3 sentences.

# %% [markdown]
# **Type Here**
